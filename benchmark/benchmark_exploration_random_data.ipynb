# %% [markdown]
# # Overview
#
#
# # Definitions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import seaborn as sns

# %%
df = pd.read_csv("results/final.csv", index_col=0)
df
# Out:
#                                 CPU TIME (ms)  GPU TIME (ms)  CPU MEMORY (MB)  \
# mt::initialization                   0.148707       0.000000         0.000000
# mt::matplotlib_visualization         0.096275       0.000000         0.000000
# mt::training::backward_pass      16058.836601       0.098106        -0.004578
# mt::training::forward_pass        9008.645257   16502.529207         0.004578
# mt::training::loss_computation     130.881281      40.716186         0.000000
# ...                                       ...            ...              ...
# mt::training::backward_pass      17207.819993       0.105984        -0.004578
# mt::training::forward_pass        8687.290144   17311.940277         0.004578
# mt::training::loss_computation      25.603876       2.359650         0.000000
# mt::training::optimizer_steps      718.579488     645.868697         0.000580
# mt::training_epoch               26664.878015    9306.759496         0.000580
#
#                                 GPU MEMORY (MB)  NCALLS  PEAK GPU MEMORY (MB)  \
# mt::initialization                     0.000000     1.0           4933.629883
# mt::matplotlib_visualization           0.000000     1.0           4933.629883
# mt::training::backward_pass       -87420.288574    25.0           4933.629883
# mt::training::forward_pass         95708.479492    25.0           4933.629883
# mt::training::loss_computation         0.623047    25.0           4933.629883
# ...                                         ...     ...                   ...
# mt::training::backward_pass       -87253.663574    25.0           7420.852539
# mt::training::forward_pass         95623.354492    25.0           7420.852539
# mt::training::loss_computation         0.623047    25.0           7420.852539
# mt::training::optimizer_steps        657.640625    25.0           7420.852539
# mt::training_epoch                   992.579590     5.0           7420.852539
#
#                                          LENS   VISUALIZER  INPLACE DEVICE
# mt::initialization                   baseline          NaN     True   cuda
# mt::matplotlib_visualization         baseline          NaN     True   cuda
# mt::training::backward_pass          baseline          NaN     True   cuda
# mt::training::forward_pass           baseline          NaN     True   cuda
# mt::training::loss_computation       baseline          NaN     True   cuda
# ...                                       ...          ...      ...    ...
# mt::training::backward_pass     ParameterNorm  tensorboard    False   cuda
# mt::training::forward_pass      ParameterNorm  tensorboard    False   cuda
# mt::training::loss_computation  ParameterNorm  tensorboard    False   cuda
# mt::training::optimizer_steps   ParameterNorm  tensorboard    False   cuda
# mt::training_epoch              ParameterNorm  tensorboard    False   cuda
#
# [238 rows x 10 columns]

# %%
def display_benchmark(df, training_part, metric, *, inplace, ax, step=0.25):
    df_ = df.loc[training_part, [metric, 'LENS', 'VISUALIZER', 'INPLACE']]
    baseline_val = df_[df_['LENS'] == 'baseline'][metric].iloc[0]
    df_ = df_[(df_['INPLACE'] == inplace) & (df_['LENS'] != 'baseline')]
    
    ax.set_title(f"{metric} / {training_part}")
    
    ax.axhline(baseline_val, c='red', label='baseline')
    sns.barplot(
        df_, x='LENS', y=metric, hue='VISUALIZER',
        ax=ax, zorder=0, legend='brief'
    )
    ax.set_xticks(ax.get_xticks())
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=15
    )
    N = round((df_[metric].max() - baseline_val) / (step * baseline_val + 1e-9)) + 1
    if N < 15:
     
        rel_yticks = [baseline_val, baseline_val * 1.1] + [baseline_val * (1 + step * k) for k in range(1, N)]
        rel_yticklabels =["+0%", "+10%"] + [f"+{step * 100 * k}%" for k in range(1, N)]
        ax_min, ax_max = ax.get_ylim()[0], max(rel_yticks)
        axr = ax.twinx()
        if not np.isclose(ax_min, ax_max):
            axr.set_ylim(ax_min, ax_max)
            ax.set_ylim(ax_min, ax_max)
        axr.set_yticks(rel_yticks, rel_yticklabels)

        axr.grid(zorder=3)
    ax.legend()
    ax.set_xlabel("Lens")

# %% [markdown]
# ## Initalization, Training and Visualisation Benchmarks

# %%
metrics = ['CPU TIME (ms)', 'GPU TIME (ms)', 'CPU MEMORY (MB)', 'GPU MEMORY (MB)', 'PEAK GPU MEMORY (MB)']

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(25, 30))
axes = axes.flatten()
for i, metric in enumerate(metrics):
    display_benchmark(
        df=df,
        training_part='mt::initialization',
        metric=metric,
        inplace=False,
        ax=axes[i],
        step=(2.00 if metric == 'CPU TIME (ms)' else 0.25)
    )

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(25, 30))
axes = axes.flatten()
for i, metric in enumerate(metrics):
    display_benchmark(
        df=df,
        training_part='mt::training_epoch',
        metric=metric,
        inplace=False,
        ax=axes[i]
    )

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(25, 30))
axes = axes.flatten()
for i, metric in enumerate(metrics):
    display_benchmark(
        df=df,
        training_part='mt::matplotlib_visualization',
        metric=metric,
        inplace=False,
        ax=axes[i]
    )

# %% [markdown]
# ## Training Benchmarks

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(25, 30))
axes = axes.flatten()
for i, metric in enumerate(metrics):
    display_benchmark(
        df=df,
        training_part='mt::training::forward_pass',
        metric=metric,
        inplace=True,
        ax=axes[i]
    )

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(25, 30))
axes = axes.flatten()
for i, metric in enumerate(metrics):
    display_benchmark(
        df=df,
        training_part='mt::training::backward_pass',
        metric=metric,
        inplace=True,
        ax=axes[i]
    )

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(25, 30))
axes = axes.flatten()
for i, metric in enumerate(metrics):
    display_benchmark(
        df=df,
        training_part='mt::training::loss_computation',
        metric=metric,
        inplace=True,
        ax=axes[i]
    )

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(25, 30))
axes = axes.flatten()
for i, metric in enumerate(metrics):
    display_benchmark(
        df=df,
        training_part='mt::training::optimizer_steps',
        metric=metric,
        inplace=True,
        ax=axes[i]
    )
