# %%
from monitorch.visualizer import PlayerVisualizer, MatplotlibVisualizer

# %%
player = PlayerVisualizer('logs/ve_do_03_ve_gate_constant_momentum.pkl', target_visualizer=MatplotlibVisualizer()).playback()

# %%
fig = player.visualizer.show_fig()

# %%
fig.savefig('figs/ve_do_03_ve_gate_constant_momentum=87.svg')
